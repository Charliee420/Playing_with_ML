# %% [markdown]
# STARTED LINER REG WITH SAMPLE DATA SET
# 1st Import all needed libs

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
week_data=[1,2,3,4,5]
sales_data=[2,4,5,4,6]
df = pd.DataFrame({"week": week_data,
                   "sales": sales_data})

# %% [markdown]
# Split X and Y

# %%
X=df["week"].values
Y=df["sales"].values

# %%
df
# Out:
#    week  sales
# 0     1      2
# 1     2      4
# 2     3      5
# 3     4      4
# 4     5      6

# %%
X
# Out:
# array([1, 2, 3, 4, 5])

# %%
Y
# Out:
# array([2, 4, 5, 4, 6])

# %% [markdown]
# Take mean of both X and Y

# %%
x_mean=np.mean(X)
y_mean=np.mean(Y)
n=len(X)
numer=0
denom=0

# %%
x_mean
y_mean
# Out:
# np.float64(4.2)
